# %% [markdown]
# # 02-12b Kaggle nnU-Net PHE-only baseline 120 epochs
#
# Notebook nay la ban Kaggle cua `02_12`: train PHE-only baseline bang nnU-Net framework, khong dung ICH teacher/prior. Khac voi `02_15`, ban nay chay 120 epoch de xem baseline co tien gan paper hon khong.
#
# Input/output:
#
# ```text
# input  channel 0 = CT
# target label     = manual PHE mask
# ```
#
# Neu upload split CSV cu thi notebook se dung split do. Neu khong co split CSV, notebook dung hardcoded val/test IDs tu split hien tai: train 99, val 10, test 11.

# %%
from pathlib import Path
import os
import sys
import json
import shutil
import time
import gc

import numpy as np
import pandas as pd

IS_KAGGLE = Path('/kaggle/input').exists()
KAGGLE_INPUT = Path('/kaggle/input')
WORK_ROOT = Path('/kaggle/working') if IS_KAGGLE else Path.cwd().resolve()
LOCAL_ROOT = Path.cwd().resolve()

# Optional manual overrides for Kaggle datasets.
# Example:
USER_NNUNET_REPO = Path('/kaggle/input/datasets/dovune/nnunet/nnUNet-master')
USER_PHE_ROOT = Path('/kaggle/input/datasets/dovune/phe-sich-ct-ids/PHE-SICH-CT-IDS/SubdatasetA_NIFIT/NIFIT')
# USER_SPLIT_CSV = Path('/kaggle/input/my-split/3dff_iph_phe_patient_split.csv')
USER_NNUNET_REPO = None
USER_PHE_ROOT = None
USER_SPLIT_CSV = None

OUTPUT_ROOT = WORK_ROOT / 'outputs_02_12b_kaggle_nnunet_phe_only_120epochs'
NNUNET_BASE = OUTPUT_ROOT / 'nnunet_workdir'
NNUNET_RAW = NNUNET_BASE / 'nnUNet_raw'
NNUNET_PREPROCESSED = NNUNET_BASE / 'nnUNet_preprocessed'
NNUNET_RESULTS = NNUNET_BASE / 'nnUNet_results'

DATASET_ID = 112
DATASET_NAME = f'Dataset{DATASET_ID:03d}_PHESICH_PHE_Only_120ep_Kaggle'
DATASET_DIR = NNUNET_RAW / DATASET_NAME

VAL_SCAN_IDS = {'0013', '0014', '0060', '0078', '0080', '0115', '0119', '0130', '0138', '0160'}
TEST_SCAN_IDS = {'0002', '0029', '0033', '0051', '0061', '0084', '0095', '0096', '0113', '0116', '0167'}

for p in [OUTPUT_ROOT, NNUNET_RAW, NNUNET_PREPROCESSED, NNUNET_RESULTS]:
    p.mkdir(parents=True, exist_ok=True)

os.environ['nnUNet_raw'] = str(NNUNET_RAW)
os.environ['nnUNet_preprocessed'] = str(NNUNET_PREPROCESSED)
os.environ['nnUNet_results'] = str(NNUNET_RESULTS)
os.environ['nnUNet_n_proc_DA'] = '0'
os.environ['nnUNet_compile'] = 'False'

print('IS_KAGGLE            :', IS_KAGGLE)
print('WORK_ROOT            :', WORK_ROOT)
print('Output root          :', OUTPUT_ROOT)
print('Dataset              :', DATASET_NAME)
print('nnUNet_raw           :', os.environ['nnUNet_raw'])
print('nnUNet_preprocessed  :', os.environ['nnUNet_preprocessed'])
print('nnUNet_results       :', os.environ['nnUNet_results'])
# Out:
# IS_KAGGLE            : True
# WORK_ROOT            : /kaggle/working
# Output root          : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs
# Dataset              : Dataset112_PHESICH_PHE_Only_120ep_Kaggle
# nnUNet_raw           : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_raw
# nnUNet_preprocessed  : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_preprocessed
# nnUNet_results       : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_results

# %% [markdown]
# ## 0. Locate framework and PHE data
#
# Upload len Kaggle toi thieu 2 dataset:
#
# - nnU-Net framework folder co `nnunetv2/__init__.py`
# - PHE-SICH NIfTI folder co `SubdatasetA_NIFIT/NIFIT/set` va `label`

# %%
def strip_nii_suffix(path_like):
    name = Path(str(path_like)).name
    if name.endswith('.nii.gz'):
        return name[:-7]
    if name.endswith('.nii'):
        return name[:-4]
    return Path(name).stem

def find_nnunet_repo():
    if USER_NNUNET_REPO is not None:
        p = Path(USER_NNUNET_REPO)
        if (p / 'nnunetv2' / '__init__.py').exists():
            return p
    candidates = [LOCAL_ROOT / 'nnUNet-master', LOCAL_ROOT]
    if IS_KAGGLE:
        candidates.extend(KAGGLE_INPUT.iterdir())
    for base in candidates:
        if (base / 'nnunetv2' / '__init__.py').exists():
            return base
        if (base / 'nnUNet-master' / 'nnunetv2' / '__init__.py').exists():
            return base / 'nnUNet-master'
    search_roots = [KAGGLE_INPUT] if IS_KAGGLE else [LOCAL_ROOT]
    for root in search_roots:
        for init_file in root.rglob('nnunetv2/__init__.py'):
            return init_file.parents[1]
    raise FileNotFoundError('Could not find nnU-Net repo. Set USER_NNUNET_REPO manually.')

def has_nifti_pair_root(path_like):
    p = Path(path_like)
    if not (p / 'set').exists() or not (p / 'label').exists():
        return False
    image_count = len(list((p / 'set').glob('*.nii'))) + len(list((p / 'set').glob('*.nii.gz')))
    mask_count = len(list((p / 'label').glob('*.nii'))) + len(list((p / 'label').glob('*.nii.gz')))
    return image_count > 0 and mask_count > 0

def find_phe_root():
    if USER_PHE_ROOT is not None:
        p = Path(USER_PHE_ROOT)
        if has_nifti_pair_root(p):
            return p
    candidates = [
        LOCAL_ROOT / 'PHE-SICH-CT-IDS' / 'SubdatasetA_NIFIT' / 'NIFIT',
        LOCAL_ROOT / 'SubdatasetA_NIFIT' / 'NIFIT',
    ]
    if IS_KAGGLE:
        for base in KAGGLE_INPUT.iterdir():
            candidates.extend([
                base / 'PHE-SICH-CT-IDS' / 'SubdatasetA_NIFIT' / 'NIFIT',
                base / 'SubdatasetA_NIFIT' / 'NIFIT',
                base / 'NIFIT',
                base,
            ])
    for p in candidates:
        if has_nifti_pair_root(p):
            return p
    search_roots = [KAGGLE_INPUT] if IS_KAGGLE else [LOCAL_ROOT]
    nifti_roots = []
    for root in search_roots:
        for set_dir in root.rglob('set'):
            p = set_dir.parent
            if has_nifti_pair_root(p):
                nifti_roots.append(p)
    if nifti_roots:
        nifti_roots = sorted(nifti_roots, key=lambda p: (('SubdatasetA_NIFIT' not in str(p)), len(str(p))))
        return nifti_roots[0]
    raise FileNotFoundError('Could not find PHE NIfTI root with .nii/.nii.gz files in set/label. Set USER_PHE_ROOT manually.')

def find_split_csv():
    if USER_SPLIT_CSV is not None and Path(USER_SPLIT_CSV).exists():
        return Path(USER_SPLIT_CSV)
    names = {'3dff_iph_phe_patient_split.csv', 'phe_split.csv', 'patient_split.csv'}
    candidates = []
    local_candidate = LOCAL_ROOT / 'outputs_02_10_pese_guided_3dff_refined_pseudo_iph_phe_25d_segmentation' / 'manifests' / '3dff_iph_phe_patient_split.csv'
    candidates.append(local_candidate)
    if IS_KAGGLE:
        for root in KAGGLE_INPUT.iterdir():
            for csv_path in root.rglob('*.csv'):
                if csv_path.name in names:
                    candidates.append(csv_path)
    for p in candidates:
        if p.exists():
            return p
    return None

NNUNET_REPO = find_nnunet_repo()
PHE_ROOT = find_phe_root()
PHE_IMAGE_DIR = PHE_ROOT / 'set'
PHE_MASK_DIR = PHE_ROOT / 'label'
SPLIT_CSV = find_split_csv()

if str(NNUNET_REPO) not in sys.path:
    sys.path.insert(0, str(NNUNET_REPO))

print('nnU-Net repo :', NNUNET_REPO)
print('PHE root     :', PHE_ROOT)
print('Image dir    :', PHE_IMAGE_DIR)
print('Mask dir     :', PHE_MASK_DIR)
print('Split CSV    :', SPLIT_CSV if SPLIT_CSV is not None else 'not found, using embedded split IDs')
print('Images       :', len(list(PHE_IMAGE_DIR.glob('*.nii*'))))
print('Masks        :', len(list(PHE_MASK_DIR.glob('*.nii*'))))
# Out:
# nnU-Net repo : /kaggle/input/datasets/dovune/nnunet/nnUNet-master
# PHE root     : /kaggle/input/datasets/dovune/phe-sich-ct-ids/PHE-SICH-CT-IDS/SubdatasetA_NIFIT/NIFIT
# Image dir    : /kaggle/input/datasets/dovune/phe-sich-ct-ids/PHE-SICH-CT-IDS/SubdatasetA_NIFIT/NIFIT/set
# Mask dir     : /kaggle/input/datasets/dovune/phe-sich-ct-ids/PHE-SICH-CT-IDS/SubdatasetA_NIFIT/NIFIT/label
# Split CSV    : not found, using embedded split IDs
# Images       : 120
# Masks        : 120

# %% [markdown]
# ## 1. Install/import dependencies
#
# Kaggle co the can bat Internet de cai dependency neu dataset framework chua kem moi package. Neu da cai san, cell nay chi import.

# %%
AUTO_INSTALL_MISSING_DEPS = True
INSTALL_NNUNET_EDITABLE = False

def ensure_import(import_name, pip_name=None):
    import importlib
    import subprocess
    pip_name = pip_name or import_name
    try:
        return importlib.import_module(import_name)
    except ModuleNotFoundError:
        if not AUTO_INSTALL_MISSING_DEPS:
            raise
        cmd = [sys.executable, '-m', 'pip', 'install', pip_name]
        print('Missing', import_name, '-> running:', ' '.join(cmd))
        subprocess.check_call(cmd)
        return importlib.import_module(import_name)

if INSTALL_NNUNET_EDITABLE:
    import subprocess
    cmd = [sys.executable, '-m', 'pip', 'install', '-e', str(NNUNET_REPO)]
    print('Running:', ' '.join(cmd))
    subprocess.check_call(cmd)

ensure_import('SimpleITK')
ensure_import('batchgenerators')
ensure_import('batchgeneratorsv2')
ensure_import('acvl_utils', 'acvl-utils')
ensure_import('dynamic_network_architectures', 'dynamic-network-architectures')
ensure_import('blosc2')
ensure_import('yacs')
ensure_import('nnunetv2')

import SimpleITK as sitk
import nnunetv2
print('SimpleITK OK')
print('nnunetv2 import OK:', nnunetv2.__file__)

EXT_TRAINER_DIR = OUTPUT_ROOT / 'nnunet_ext_trainers'
EXT_TRAINER_DIR.mkdir(parents=True, exist_ok=True)
trainer_120_file = EXT_TRAINER_DIR / 'nnUNetTrainer_120epochs.py'
trainer_120_file.write_text("""import torch\n\nfrom nnunetv2.training.nnUNetTrainer.nnUNetTrainer import nnUNetTrainer\n\n\nclass nnUNetTrainer_120epochs(nnUNetTrainer):\n    def __init__(self, plans: dict, configuration: str, fold: int, dataset_json: dict, device: torch.device = torch.device('cuda')):\n        super().__init__(plans, configuration, fold, dataset_json, device)\n        self.num_epochs = 120\n""", encoding='utf-8')
os.environ['nnUNet_extTrainer'] = str(EXT_TRAINER_DIR)
print('External trainer dir:', os.environ['nnUNet_extTrainer'])
# Out:
# Missing batchgenerators -> running: /usr/bin/python3 -m pip install batchgenerators
# Collecting batchgenerators
#   Downloading batchgenerators-0.25.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (11.3.0)
# Requirement already satisfied: numpy>=1.10.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (2.4.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (1.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (2.3.3)
# Collecting unittest2 (from batchgenerators)
#   Downloading unittest2-1.1.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators) (2026.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->batchgenerators) (1.5.3)
# Collecting argparse (from unittest2->batchgenerators)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators) (1.17.0)
# Collecting traceback2 (from unittest2->batchgenerators)
#   Downloading traceback2-1.4.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting linecache2 (from traceback2->unittest2->batchgenerators)
#   Downloading linecache2-1.0.0-py2.py3-none-any.whl.metadata (1000 bytes)
# Downloading batchgenerators-0.25.3-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 3.8 MB/s eta 0:00:00
# Downloading unittest2-1.1.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 7.8 MB/s eta 0:00:00
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading traceback2-1.4.0-py2.py3-none-any.whl (16 kB)
# Downloading linecache2-1.0.0-py2.py3-none-any.whl (12 kB)
# Installing collected packages: linecache2, argparse, traceback2, unittest2, batchgenerators
# Successfully installed argparse-1.4.0 batchgenerators-0.25.3 linecache2-1.0.0 traceback2-1.4.0 unittest2-1.1.0
# Missing batchgeneratorsv2 -> running: /usr/bin/python3 -m pip install batchgeneratorsv2
# Collecting batchgeneratorsv2
#   Downloading batchgeneratorsv2-0.3.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from batchgeneratorsv2) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from batchgeneratorsv2) (2.4.6)
# Requirement already satisfied: batchgenerators>=0.25 in /usr/local/lib/python3.12/dist-packages (from batchgeneratorsv2) (0.25.3)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (1.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (2.3.3)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (1.1.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25->batchgeneratorsv2) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (2025.3.0)
# Collecting cuda-bindings==12.9.4 (from torch>=2.0.0->batchgeneratorsv2)
#   Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->batchgeneratorsv2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->batchgeneratorsv2) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->batchgeneratorsv2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->batchgeneratorsv2) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators>=0.25->batchgeneratorsv2) (2026.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators>=0.25->batchgeneratorsv2) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators>=0.25->batchgeneratorsv2) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators>=0.25->batchgeneratorsv2) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->batchgenerators>=0.25->batchgeneratorsv2) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->batchgenerators>=0.25->batchgeneratorsv2) (1.5.3)
# Collecting argparse (from unittest2->batchgenerators>=0.25->batchgeneratorsv2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators>=0.25->batchgeneratorsv2) (1.17.0)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators>=0.25->batchgeneratorsv2) (1.4.0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.12/dist-packages (from traceback2->unittest2->batchgenerators>=0.25->batchgeneratorsv2) (1.0.0)
# Downloading batchgeneratorsv2-0.3.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 2.3 MB/s eta 0:00:00
# Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 92.7 MB/s eta 0:00:00
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse, cuda-bindings, batchgeneratorsv2
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Successfully installed argparse-1.4.0 batchgeneratorsv2-0.3.3 cuda-bindings-12.9.4
# Missing acvl_utils -> running: /usr/bin/python3 -m pip install acvl-utils
# Collecting acvl-utils
#   Downloading acvl_utils-0.2.6.tar.gz (34 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (2.4.6)
# Requirement already satisfied: batchgenerators in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (0.25.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (2.10.0+cu128)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (2.5.5)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (0.25.2)
# Collecting connected-components-3d (from acvl-utils)
#   Downloading connected_components_3d-4.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: blosc2>=3.0.0b4 in /usr/local/lib/python3.12/dist-packages (from acvl-utils) (4.1.2)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b4->acvl-utils) (1.10.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b4->acvl-utils) (1.1.2)
# Requirement already satisfied: numexpr>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b4->acvl-utils) (2.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b4->acvl-utils) (2.32.4)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (1.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (2.3.3)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (1.1.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators->acvl-utils) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->acvl-utils) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->acvl-utils) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->acvl-utils) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->acvl-utils) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->acvl-utils) (0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->acvl-utils) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->acvl-utils) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->acvl-utils) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->acvl-utils) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators->acvl-utils) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators->acvl-utils) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->batchgenerators->acvl-utils) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=3.0.0b4->acvl-utils) (2026.2.25)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->batchgenerators->acvl-utils) (1.5.3)
# Collecting argparse (from unittest2->batchgenerators->acvl-utils)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators->acvl-utils) (1.17.0)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators->acvl-utils) (1.4.0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.12/dist-packages (from traceback2->unittest2->batchgenerators->acvl-utils) (1.0.0)
# Downloading connected_components_3d-4.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 52.5 MB/s eta 0:00:00
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: acvl-utils
#   Building wheel for acvl-utils (pyproject.toml): started
#   Building wheel for acvl-utils (pyproject.toml): finished with status 'done'
#   Created wheel for acvl-utils: filename=acvl_utils-0.2.6-py3-none-any.whl size=32247 sha256=cb3c976ff3985ba011155016b8d8bfb79b16c35034a91c11eccecb81dc6cd41e
#   Stored in directory: /root/.cache/pip/wheels/99/bd/6c/fde792318e559dd66b111b2c6330e15902c6ec9b05d0219d7a
# Successfully built acvl-utils
# Installing collected packages: argparse, connected-components-3d, acvl-utils
# Successfully installed acvl-utils-0.2.6 argparse-1.4.0 connected-components-3d-4.0.0
# Missing dynamic_network_architectures -> running: /usr/bin/python3 -m pip install dynamic-network-architectures
# Collecting dynamic-network-architectures
#   Downloading dynamic_network_architectures-0.4.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch>=1.6.0a in /usr/local/lib/python3.12/dist-packages (from dynamic-network-architectures) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from dynamic-network-architectures) (2.4.6)
# Collecting timm<1.0.23 (from dynamic-network-architectures)
#   Downloading timm-1.0.22-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from dynamic-network-architectures) (0.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures) (0.25.0+cu128)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures) (1.10.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->dynamic-network-architectures) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.6.0a->dynamic-network-architectures) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0a->dynamic-network-architectures) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures) (26.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0a->dynamic-network-architectures) (3.0.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm<1.0.23->dynamic-network-architectures) (11.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm<1.0.23->dynamic-network-architectures) (0.1.2)
# Downloading dynamic_network_architectures-0.4.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.6 MB/s eta 0:00:00
# Downloading timm-1.0.22-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.6 MB/s eta 0:00:00
# Installing collected packages: timm, dynamic-network-architectures
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.26
#     Uninstalling timm-1.0.26:
#       Successfully uninstalled timm-1.0.26
# Successfully installed dynamic-network-architectures-0.4.4 timm-1.0.22
# Missing yacs -> running: /usr/bin/python3 -m pip install yacs
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs) (6.0.3)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8
# SimpleITK OK
# nnunetv2 import OK: /kaggle/input/datasets/dovune/nnunet/nnUNet-master/nnunetv2/__init__.py
# External trainer dir: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers

# %% [markdown]
# ## 2. Build PHE-only split manifest

# %%
def make_case_id(scan_id):
    scan_id = str(scan_id).strip()
    if scan_id.lower().startswith('phe_'):
        return scan_id
    if scan_id.isdigit():
        return f'phe_{int(scan_id):04d}'
    safe = ''.join(ch if ch.isalnum() else '_' for ch in scan_id).strip('_')
    return f'phe_{safe}'

def find_nii_by_scan(folder, scan_id):
    scan_id = str(scan_id).strip()
    candidates = [
        folder / f'{scan_id}.nii.gz',
        folder / f'{scan_id}.nii',
        folder / f'{int(scan_id):04d}.nii.gz' if scan_id.isdigit() else folder / f'{scan_id}.nii.gz',
        folder / f'{int(scan_id):04d}.nii' if scan_id.isdigit() else folder / f'{scan_id}.nii',
    ]
    for p in candidates:
        if p.exists():
            return p
    raise FileNotFoundError(f'Missing NIfTI for scan_id={scan_id} in {folder}')

def split_from_scan_id(scan_id):
    scan_id = str(scan_id).strip()
    scan_id4 = f'{int(scan_id):04d}' if scan_id.isdigit() else scan_id
    if scan_id4 in TEST_SCAN_IDS:
        return 'test'
    if scan_id4 in VAL_SCAN_IDS:
        return 'val'
    return 'train'

if SPLIT_CSV is not None:
    raw_split_df = pd.read_csv(SPLIT_CSV, dtype={'scan_id': str, 'patient_id': str})
    raw_split_df.columns = [str(c).strip() for c in raw_split_df.columns]
    rows = []
    for row in raw_split_df.itertuples(index=False):
        row_dict = row._asdict()
        scan_id = row_dict.get('scan_id', None) or row_dict.get('patient_id', None)
        if scan_id is None or pd.isna(scan_id) or str(scan_id).strip() == '':
            img_path_value = row_dict.get('img_path', '')
            scan_id = strip_nii_suffix(img_path_value)
        scan_id = f'{int(str(scan_id)):04d}' if str(scan_id).isdigit() else str(scan_id).strip()
        split_value = str(row_dict.get('split', split_from_scan_id(scan_id))).strip().lower()
        img_path = Path(str(row_dict.get('img_path', '')))
        mask_path = Path(str(row_dict.get('phe_mask_path', '')))
        if not img_path.exists():
            img_path = find_nii_by_scan(PHE_IMAGE_DIR, scan_id)
        if not mask_path.exists():
            mask_path = find_nii_by_scan(PHE_MASK_DIR, scan_id)
        rows.append({'scan_id': scan_id, 'case_id': make_case_id(scan_id), 'split': split_value, 'img_path': str(img_path), 'phe_mask_path': str(mask_path)})
    split_df = pd.DataFrame(rows)
else:
    rows = []
    for img_path in sorted(PHE_IMAGE_DIR.glob('*.nii*')):
        scan_id = strip_nii_suffix(img_path)
        mask_path = find_nii_by_scan(PHE_MASK_DIR, scan_id)
        rows.append({'scan_id': scan_id, 'case_id': make_case_id(scan_id), 'split': split_from_scan_id(scan_id), 'img_path': str(img_path), 'phe_mask_path': str(mask_path)})
    split_df = pd.DataFrame(rows)

assert split_df['case_id'].is_unique, 'case_id must be unique.'
assert split_df['img_path'].map(lambda x: Path(x).exists()).all(), 'Some images are missing.'
assert split_df['phe_mask_path'].map(lambda x: Path(x).exists()).all(), 'Some masks are missing.'

split_df.to_csv(OUTPUT_ROOT / '02_12b_kaggle_phe_only_split_manifest.csv', index=False)
display(split_df.groupby('split').size().rename('cases').reset_index())
display(split_df.head())
# Out:
#    split  cases
# 0   test     11
# 1  train     99
# 2    val     10
#   scan_id   case_id  split                                           img_path  \
# 0    0001  phe_0001  train  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 1    0002  phe_0002   test  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 2    0004  phe_0004  train  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 3    0005  phe_0005  train  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 4    0006  phe_0006  train  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
#
#                                        phe_mask_path
# 0  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 1  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 2  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 3  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...
# 4  /kaggle/input/datasets/dovune/phe-sich-ct-ids/...

# %% [markdown]
# ## 3. Convert PHE-only raw dataset

# %%
OVERWRITE_RAW_DATASET = True

def write_binary_label(src_path: Path, reference_path: Path, dst_path: Path):
    src_path = Path(src_path)
    reference_path = Path(reference_path)
    dst_path = Path(dst_path)
    ref = sitk.ReadImage(str(reference_path))
    seg = sitk.ReadImage(str(src_path))
    arr = sitk.GetArrayFromImage(seg)
    out = sitk.GetImageFromArray((arr > 0).astype(np.uint8))
    if ref.GetSize() != out.GetSize():
        raise ValueError(f'Size mismatch: {reference_path} {ref.GetSize()} vs {src_path} {out.GetSize()}')
    out.CopyInformation(ref)
    sitk.WriteImage(out, str(dst_path))

if DATASET_DIR.exists() and OVERWRITE_RAW_DATASET:
    shutil.rmtree(DATASET_DIR)

imagesTr = DATASET_DIR / 'imagesTr'
labelsTr = DATASET_DIR / 'labelsTr'
imagesTs = DATASET_DIR / 'imagesTs'
labelsTs = DATASET_DIR / 'labelsTs'
for p in [imagesTr, labelsTr, imagesTs, labelsTs]:
    p.mkdir(parents=True, exist_ok=True)

records = []
for row in split_df.itertuples(index=False):
    case_id = str(row.case_id)
    img_src = Path(row.img_path)
    phe_src = Path(row.phe_mask_path)
    if row.split == 'test':
        img_dst = imagesTs / f'{case_id}_0000.nii.gz'
        seg_dst = labelsTs / f'{case_id}.nii.gz'
    else:
        img_dst = imagesTr / f'{case_id}_0000.nii.gz'
        seg_dst = labelsTr / f'{case_id}.nii.gz'
    shutil.copy2(img_src, img_dst)
    write_binary_label(phe_src, img_dst, seg_dst)
    records.append({'scan_id': row.scan_id, 'case_id': case_id, 'split': row.split, 'nnunet_image': str(img_dst), 'nnunet_label': str(seg_dst)})

dataset_json = {
    'channel_names': {'0': 'CT'},
    'labels': {'background': 0, 'PHE': 1},
    'numTraining': int((split_df['split'] != 'test').sum()),
    'file_ending': '.nii.gz',
    'overwrite_image_reader_writer': 'SimpleITKIO',
}
with open(DATASET_DIR / 'dataset.json', 'w', encoding='utf-8') as f:
    json.dump(dataset_json, f, indent=2)

conversion_df = pd.DataFrame(records)
conversion_df.to_csv(OUTPUT_ROOT / '02_12b_kaggle_phe_only_conversion_manifest.csv', index=False)

print('Dataset dir:', DATASET_DIR)
print('imagesTr:', len(list(imagesTr.glob('*.nii.gz'))))
print('labelsTr:', len(list(labelsTr.glob('*.nii.gz'))))
print('imagesTs:', len(list(imagesTs.glob('*.nii.gz'))))
print('labelsTs:', len(list(labelsTs.glob('*.nii.gz'))))
display(conversion_df.groupby('split').size().rename('cases').reset_index())
# Out:
# Dataset dir: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_raw/Dataset112_PHESICH_PHE_Only_120ep_Kaggle
# imagesTr: 109
# labelsTr: 109
# imagesTs: 11
# labelsTs: 11
#    split  cases
# 0   test     11
# 1  train     99
# 2    val     10

# %% [markdown]
# ## 3b. Sanity check PHE labels
#
# Chay cell nay truoc khi train neu `Pseudo dice` bi 0. Neu `nonzero_voxels` cua val/test > 0 thi label khong bi rong; Dice 0 o epoch dau thuong chi la model dang predict background.

# %%
CHECK_LABELS = True

if CHECK_LABELS:
    qc_rows = []
    for row in conversion_df.itertuples(index=False):
        seg = sitk.ReadImage(str(row.nnunet_label))
        arr = sitk.GetArrayFromImage(seg)
        values = np.unique(arr)
        qc_rows.append({
            'case_id': row.case_id,
            'split': row.split,
            'shape_zyx': tuple(arr.shape),
            'unique_values': values.tolist(),
            'nonzero_voxels': int((arr > 0).sum()),
        })
    label_qc_df = pd.DataFrame(qc_rows)
    display(label_qc_df.groupby('split').agg(
        cases=('case_id', 'count'),
        positive_cases=('nonzero_voxels', lambda s: int((s > 0).sum())),
        min_nonzero=('nonzero_voxels', 'min'),
        median_nonzero=('nonzero_voxels', 'median'),
        max_nonzero=('nonzero_voxels', 'max'),
    ).reset_index())
    zero_cases = label_qc_df.loc[label_qc_df['nonzero_voxels'] == 0, ['case_id', 'split']]
    if len(zero_cases):
        print('WARNING: empty PHE labels found:')
        display(zero_cases)
    else:
        print('All converted PHE labels have foreground voxels.')
else:
    print('Skipped label QC.')
# Out:
#    split  cases  positive_cases  min_nonzero  median_nonzero  max_nonzero
# 0   test     11              11          240          1635.0         6416
# 1  train     99              99           70          2423.0        19362
# 2    val     10              10          463          2352.0         7467
# All converted PHE labels have foreground voxels.

# %% [markdown]
# ## 4. nnU-Net helper

# %%
def call_entrypoint(entrypoint_func, argv):
    old_argv = sys.argv[:]
    sys.argv = list(argv)
    print('>>>', ' '.join(map(str, sys.argv)))
    t0 = time.time()
    try:
        return entrypoint_func()
    finally:
        sys.argv = old_argv
        print(f'Done in {(time.time() - t0) / 60:.1f} min')

# %% [markdown]
# ## 5. Plan and preprocess

# %%
CONFIGURATION = '3d_fullres'
RUN_PLAN_PREPROCESS = True

if RUN_PLAN_PREPROCESS:
    from nnunetv2.experiment_planning.plan_and_preprocess_entrypoints import plan_and_preprocess_entry
    old_n_proc_da = os.environ.get('nnUNet_n_proc_DA')
    os.environ['nnUNet_n_proc_DA'] = '1'
    try:
        call_entrypoint(plan_and_preprocess_entry, [
            'nnUNetv2_plan_and_preprocess',
            '-d', str(DATASET_ID),
            '-c', CONFIGURATION,
            '--verify_dataset_integrity',
            '-npfp', '2',
            '-np', '1',
        ])
    finally:
        os.environ['nnUNet_n_proc_DA'] = old_n_proc_da if old_n_proc_da is not None else '0'
else:
    print('Skipped. Set RUN_PLAN_PREPROCESS=True to run.')
# Out:
# >>> nnUNetv2_plan_and_preprocess -d 112 -c 3d_fullres --verify_dataset_integrity -npfp 2 -np 1
# Fingerprint extraction...
# Dataset112_PHESICH_PHE_Only_120ep_Kaggle
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# Extracting dataset fingerprint: 100%|██████████| 109/109 [00:16<00:00,  6.47it/s]
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Attempting to find 3d_lowres config.
# Current spacing: [5.         0.50292969 0.50292969].
# Current patch size: (np.int64(16), np.int64(320), np.int64(320)).
# Current median shape: [ 30.         497.08737864 497.08737864]
# Attempting to find 3d_lowres config.
# Current spacing: [5.         0.51801758 0.51801758].
# Current patch size: (np.int64(16), np.int64(320), np.int64(320)).
# Current median shape: [ 30.         482.60910548 482.60910548]
# Attempting to find 3d_lowres config.
# Current spacing: [5.         0.53355811 0.53355811].
# Current patch size: (np.int64(20), np.int64(320), np.int64(256)).
# Current median shape: [ 30.         468.55252959 468.55252959]
# Attempting to find 3d_lowres config.
# Current spacing: [5.         0.54956485 0.54956485].
# Current patch size: (np.int64(20), np.int64(320), np.int64(256)).
# Current median shape: [ 30.         454.90536853 454.90536853]
# Dropping 3d_lowres config because the image size difference to 3d_fullres is too small. 3d_fullres: [ 30. 512. 512.], 3d_lowres: [30, 455, 455]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 12, 'patch_size': (np.int64(512), np.int64(512)), 'median_image_size_in_voxels': array([512., 512.]), 'spacing': array([0.48828125, 0.48828125]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 8, 'features_per_stage': (32, 64, 128, 256, 512, 512, 512, 512), 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': ((3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3)), 'strides': ((1, 1), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': (np.int64(16), np.int64(320), np.int64(320)), 'median_image_size_in_voxels': array([ 30., 512., 512.]), 'spacing': array([5.        , 0.48828125, 0.48828125]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': (32, 64, 128, 256, 320, 320, 320), 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': ((1, 3, 3), (1, 3, 3), (1, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3)), 'strides': ((1, 1, 1), (1, 2, 2), (1, 2, 2), (1, 2, 2), (2, 2, 2), (2, 2, 2), (1, 2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': False}
#
# Plans were saved to /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_preprocessed/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset112_PHESICH_PHE_Only_120ep_Kaggle
# Configuration: 3d_fullres...
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': [16, 320, 320], 'median_image_size_in_voxels': [30.0, 512.0, 512.0], 'spacing': [5.0, 0.48828125, 0.48828125], 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': [32, 64, 128, 256, 320, 320, 320], 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': [[1, 3, 3], [1, 3, 3], [1, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'strides': [[1, 1, 1], [1, 2, 2], [1, 2, 2], [1, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 2]], 'n_conv_per_stage': [2, 2, 2, 2, 2, 2, 2], 'n_conv_per_stage_decoder': [2, 2, 2, 2, 2, 2], 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ['conv_op', 'norm_op', 'dropout_op', 'nonlin']}, 'batch_dice': False}
# Preprocessing cases: 100%|██████████| 109/109 [02:11<00:00,  1.20s/it]
# Done in 2.9 min

# %% [markdown]
# ## 6. Write manual fold-0 split

# %%
preprocessed_dataset_dir = NNUNET_PREPROCESSED / DATASET_NAME
split_json_path = preprocessed_dataset_dir / 'splits_final.json'

train_ids = split_df.loc[split_df['split'] == 'train', 'case_id'].astype(str).tolist()
val_ids = split_df.loc[split_df['split'] == 'val', 'case_id'].astype(str).tolist()
test_ids = split_df.loc[split_df['split'] == 'test', 'case_id'].astype(str).tolist()

manual_splits = [{'train': train_ids, 'val': val_ids}]

if preprocessed_dataset_dir.exists():
    with open(split_json_path, 'w', encoding='utf-8') as f:
        json.dump(manual_splits, f, indent=2)
    print('Wrote:', split_json_path)
    print('train:', len(train_ids), 'val:', len(val_ids), 'test:', len(test_ids))
else:
    print('Preprocessed folder not found yet:', preprocessed_dataset_dir)
    print('Run plan/preprocess first, then rerun this cell.')
# Out:
# Wrote: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_preprocessed/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/splits_final.json
# train: 99 val: 10 test: 11

# %% [markdown]
# ## 7. Train PHE-only model
#
# Ban nay dung custom trainer `nnUNetTrainer_120epochs`, duoc tao tam trong `/kaggle/working` qua `nnUNet_extTrainer`. Framework upload len Kaggle khong can sua.

# %%
RUN_TRAIN = True
FOLD = 0
TRAINER = 'nnUNetTrainer_120epochs'
PLANS = 'nnUNetPlans'
EXPORT_VAL_NPZ = True
CONTINUE_TRAINING = True

if RUN_TRAIN:
    import torch
    from nnunetv2.run.run_training import run_training
    os.environ['nnUNet_n_proc_DA'] = '0'
    os.environ['nnUNet_compile'] = 'False'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Training device:', device)
    print('nnUNet_n_proc_DA:', os.environ.get('nnUNet_n_proc_DA'))
    print('nnUNet_compile:', os.environ.get('nnUNet_compile'))
    run_training(
        str(DATASET_ID),
        CONFIGURATION,
        str(FOLD),
        trainer_class_name=TRAINER,
        plans_identifier=PLANS,
        export_validation_probabilities=EXPORT_VAL_NPZ,
        continue_training=CONTINUE_TRAINING,
        device=device,
    )
else:
    print('Skipped. Set RUN_TRAIN=True to train.')
# Out:
# Training device: cuda
# nnUNet_n_proc_DA: 0
# nnUNet_compile: False
#
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Trainer 'nnUNetTrainer_120epochs' not found in nnunetv2.training.nnUNetTrainer.
# Searching in external trainer paths from environment variable 'nnUNet_extTrainer'...
# Searching in: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers
# Searching for class nnUNetTrainer_120epochs in folder /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers with current module None
#   Inspecting module: nnUNetTrainer_120epochs
# Found class nnUNetTrainer_120epochs in nnUNetTrainer_120epochs
# Using trainer 'nnUNetTrainer_120epochs' from: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# WARNING: Cannot continue training because there seems to be no checkpoint available to continue from. Starting a new training...
# 2026-06-17 13:50:02.112317: do_dummy_2d_data_aug: True
# 2026-06-17 13:50:02.114117: Using splits from existing split file: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_preprocessed/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/splits_final.json
# 2026-06-17 13:50:02.114400: The split file contains 1 splits.
# 2026-06-17 13:50:02.114501: Desired fold for training: 0
# 2026-06-17 13:50:02.114589: This split has 99 training and 10 validation cases.
#
# This is the configuration used by this training:
# Configuration name: 3d_fullres
#  {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': [16, 320, 320], 'median_image_size_in_voxels': [30.0, 512.0, 512.0], 'spacing': [5.0, 0.48828125, 0.48828125], 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': [32, 64, 128, 256, 320, 320, 320], 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': [[1, 3, 3], [1, 3, 3], [1, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'strides': [[1, 1, 1], [1, 2, 2], [1, 2, 2], [1, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 2]], 'n_conv_per_stage': [2, 2, 2, 2, 2, 2, 2], 'n_conv_per_stage_decoder': [2, 2, 2, 2, 2, 2], 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ['conv_op', 'norm_op', 'dropout_op', 'nonlin']}, 'batch_dice': False}
#
# These are the global plan.json settings:
#  {'dataset_name': 'Dataset112_PHESICH_PHE_Only_120ep_Kaggle', 'plans_name': 'nnUNetPlans', 'original_median_spacing_after_transp': [5.0, 0.48828125, 0.48828125], 'original_median_shape_after_transp': [30, 512, 512], 'image_reader_writer': 'SimpleITKIO', 'transpose_forward': [0, 1, 2], 'transpose_backward': [0, 1, 2], 'experiment_planner_used': 'ExperimentPlanner', 'label_manager': 'LabelManager', 'foreground_intensity_properties_per_channel': {'0': {'max': 99.0, 'mean': 24.356813430786133, 'median': 24.0, 'min': -2.0, 'percentile_00_5': 12.0, 'percentile_99_5': 63.0, 'std': 6.437613487243652}}}
#
# 2026-06-17 13:50:02.595468: Unable to plot network architecture:
# 2026-06-17 13:50:02.595614: No module named 'hiddenlayer'
# 2026-06-17 13:50:02.616740:
# 2026-06-17 13:50:02.616887: Epoch 0
# 2026-06-17 13:50:02.617019: Current learning rate: 0.01
# 2026-06-17 13:54:42.818687: train_loss 0.0535
# 2026-06-17 13:54:42.819318: val_loss 0.0106
# 2026-06-17 13:54:42.820091: Pseudo dice [np.float32(0.0)]
# 2026-06-17 13:54:42.820432: Epoch time: 280.2 s
# 2026-06-17 13:54:42.820606: Yayy! New best EMA pseudo Dice: 0.0
# 2026-06-17 13:54:44.242836:
# 2026-06-17 13:54:44.243093: Epoch 1
# 2026-06-17 13:54:44.243548: Current learning rate: 0.00992
# 2026-06-17 13:59:11.684238: train_loss -0.0145
# 2026-06-17 13:59:11.684667: val_loss -0.0635
# 2026-06-17 13:59:11.685203: Pseudo dice [np.float32(0.0)]
# 2026-06-17 13:59:11.685396: Epoch time: 267.44 s
# 2026-06-17 13:59:12.881603:
# 2026-06-17 13:59:12.881891: Epoch 2
# 2026-06-17 13:59:12.882314: Current learning rate: 0.00985
# 2026-06-17 14:03:40.834372: train_loss -0.1336
# 2026-06-17 14:03:40.834787: val_loss -0.2728
# 2026-06-17 14:03:40.835279: Pseudo dice [np.float32(0.3558)]
# 2026-06-17 14:03:40.835463: Epoch time: 267.95 s
# 2026-06-17 14:03:40.835598: Yayy! New best EMA pseudo Dice: 0.035599999129772186
# 2026-06-17 14:03:42.737331:
# 2026-06-17 14:03:42.737604: Epoch 3
# 2026-06-17 22:51:01.462501: phe_0060, shape torch.Size([1, 32, 512, 512]), rank 0
# 2026-06-17 22:51:30.848939: predicting phe_0078
# 2026-06-17 22:51:30.878895: phe_0078, shape torch.Size([1, 25, 512, 512]), rank 0
# 2026-06-17 22:52:00.042312: predicting phe_0080
# 2026-06-17 22:52:00.069681: phe_0080, shape torch.Size([1, 32, 512, 512]), rank 0
# 2026-06-17 22:52:29.156202: predicting phe_0115
# 2026-06-17 22:52:29.185851: phe_0115, shape torch.Size([1, 32, 543, 543]), rank 0
# 2026-06-17 22:52:58.236234: predicting phe_0119
# 2026-06-17 22:52:58.264813: phe_0119, shape torch.Size([1, 30, 512, 512]), rank 0
# 2026-06-17 22:53:27.397043: predicting phe_0130
# 2026-06-17 22:53:27.425418: phe_0130, shape torch.Size([1, 25, 512, 512]), rank 0
# 2026-06-17 22:53:56.546588: predicting phe_0138
# 2026-06-17 22:53:56.573820: phe_0138, shape torch.Size([1, 25, 512, 512]), rank 0
# 2026-06-17 22:54:25.806901: predicting phe_0160
# 2026-06-17 22:54:25.827899: phe_0160, shape torch.Size([1, 24, 451, 451]), rank 0
# 2026-06-17 22:54:46.622396: Validation complete
# 2026-06-17 22:54:46.622747: Mean Validation Dice:  0.40050798698737483

# %% [markdown]
# ## 8. Predict and evaluate test set

# %%
RUN_PREDICT = True
RUN_EVALUATE = True
DISABLE_TTA = False
CHECKPOINT = 'auto'

MODEL_DIR = NNUNET_RESULTS / DATASET_NAME / f'{TRAINER}__{PLANS}__{CONFIGURATION}'
FOLD_DIR = MODEL_DIR / f'fold_{FOLD}'

def resolve_checkpoint_name(checkpoint_setting='auto'):
    if checkpoint_setting != 'auto':
        ckpt = FOLD_DIR / checkpoint_setting
        if not ckpt.exists():
            available = sorted(p.name for p in FOLD_DIR.glob('checkpoint*.pth')) if FOLD_DIR.exists() else []
            raise FileNotFoundError(f'Missing checkpoint: {ckpt}. Available: {available}')
        return checkpoint_setting
    for name in ['checkpoint_best.pth', 'checkpoint_final.pth', 'checkpoint_latest.pth']:
        if (FOLD_DIR / name).exists():
            return name
    available = sorted(p.name for p in FOLD_DIR.glob('checkpoint*.pth')) if FOLD_DIR.exists() else []
    raise FileNotFoundError(f'No checkpoint found in {FOLD_DIR}. Available: {available}')

RESOLVED_CHECKPOINT = resolve_checkpoint_name(CHECKPOINT)
PRED_DIR = OUTPUT_ROOT / f'predictions_{CONFIGURATION}_{TRAINER}_fold{FOLD}_{RESOLVED_CHECKPOINT.replace(".pth", "")}'
SUMMARY_JSON = PRED_DIR / 'summary.json'

print('Model dir        :', MODEL_DIR)
print('Fold dir         :', FOLD_DIR)
print('Using checkpoint :', RESOLVED_CHECKPOINT)

if RUN_PREDICT:
    import torch
    from nnunetv2.inference.predict_from_raw_data import nnUNetPredictor
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Predict device:', device)
    predictor = nnUNetPredictor(
        tile_step_size=0.5,
        use_gaussian=True,
        use_mirroring=not DISABLE_TTA,
        perform_everything_on_device=(device.type == 'cuda'),
        device=device,
        verbose=False,
        verbose_preprocessing=False,
        allow_tqdm=True,
    )
    predictor.initialize_from_trained_model_folder(
        str(MODEL_DIR),
        use_folds=(FOLD,),
        checkpoint_name=RESOLVED_CHECKPOINT,
    )
    predictor.predict_from_files(
        str(imagesTs),
        str(PRED_DIR),
        save_probabilities=False,
        overwrite=True,
        num_processes_preprocessing=1,
        num_processes_segmentation_export=1,
        folder_with_segs_from_prev_stage=None,
        num_parts=1,
        part_id=0,
    )
else:
    print('Skipped prediction. Set RUN_PREDICT=True to run inference.')

if RUN_EVALUATE:
    from nnunetv2.evaluation.evaluate_predictions import evaluate_folder_entry_point
    plans_file = NNUNET_PREPROCESSED / DATASET_NAME / f'{PLANS}.json'
    dataset_json_file = DATASET_DIR / 'dataset.json'
    call_entrypoint(evaluate_folder_entry_point, [
        'nnUNetv2_evaluate_folder',
        str(labelsTs),
        str(PRED_DIR),
        '-djfile', str(dataset_json_file),
        '-pfile', str(plans_file),
        '-o', str(SUMMARY_JSON),
        '-np', '2',
    ])
else:
    print('Skipped evaluation. Set RUN_EVALUATE=True after prediction.')

print('Prediction dir:', PRED_DIR)
print('Summary json  :', SUMMARY_JSON)
# Out:
# Model dir        : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_results/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/nnUNetTrainer_120epochs__nnUNetPlans__3d_fullres
# Fold dir         : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_results/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/nnUNetTrainer_120epochs__nnUNetPlans__3d_fullres/fold_0
# Using checkpoint : checkpoint_best.pth
# Predict device: cuda
# Trainer 'nnUNetTrainer_120epochs' not found in nnunetv2.training.nnUNetTrainer.
# Searching in external trainer paths from environment variable 'nnUNet_extTrainer'...
# Searching in: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers
# Searching for class nnUNetTrainer_120epochs in folder /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers with current module None
#   Inspecting module: nnUNetTrainer_120epochs
# Found class nnUNetTrainer_120epochs in nnUNetTrainer_120epochs
# Using trainer 'nnUNetTrainer_120epochs' from: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_ext_trainers
# There are 11 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 11 cases that I would like to predict
#
# Predicting phe_0002:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:29<00:00,  1.10s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0002
#
# Predicting phe_0029:
# perform_everything_on_device: True
# 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0029
#
# Predicting phe_0033:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.04s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0033
#
# Predicting phe_0051:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.04s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0051
#
# Predicting phe_0061:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:29<00:00,  1.09s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0061
#
# Predicting phe_0084:
# perform_everything_on_device: True
# 100%|██████████| 12/12 [00:12<00:00,  1.05s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0084
#
# Predicting phe_0095:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.05s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0095
#
# Predicting phe_0096:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.06s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0096
#
# Predicting phe_0113:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.07s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0113
#
# Predicting phe_0116:
# perform_everything_on_device: True
# 100%|██████████| 27/27 [00:28<00:00,  1.07s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0116
#
# Predicting phe_0167:
# perform_everything_on_device: True
# 100%|██████████| 12/12 [00:12<00:00,  1.05s/it]
# sending off prediction to background worker for resampling and export
# done with phe_0167
# GPU prediction completed. Waiting for remaining segmentation exports to finish...
# Collecting results: 100%|██████████| 11/11 [00:00<00:00, 13.83it/s]
# Segmentation export complete.
# >>> nnUNetv2_evaluate_folder /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_raw/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/labelsTs /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/predictions_3d_fullres_nnUNetTrainer_120epochs_fold0_checkpoint_best -djfile /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_raw/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/dataset.json -pfile /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/nnunet_workdir/nnUNet_preprocessed/Dataset112_PHESICH_PHE_Only_120ep_Kaggle/nnUNetPlans.json -o /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/predictions_3d_fullres_nnUNetTrainer_120epochs_fold0_checkpoint_best/summary.json -np 2
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# Done in 0.1 min
# Prediction dir: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/predictions_3d_fullres_nnUNetTrainer_120epochs_fold0_checkpoint_best
# Summary json  : /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/predictions_3d_fullres_nnUNetTrainer_120epochs_fold0_checkpoint_best/summary.json

# %% [markdown]
# ## 9. Export compact metrics CSV

# %%
if SUMMARY_JSON.exists():
    with open(SUMMARY_JSON, 'r', encoding='utf-8') as f:
        summary = json.load(f)

    rows = []
    for item in summary.get('metric_per_case', []):
        metrics = item.get('metrics', {}).get('1', {})
        rows.append({
            'case_id': strip_nii_suffix(item.get('prediction_file', '')),
            'prediction_file': item.get('prediction_file', ''),
            'reference_file': item.get('reference_file', ''),
            **metrics,
        })
    metrics_df = pd.DataFrame(rows)
    metrics_csv = OUTPUT_ROOT / '02_12b_kaggle_phe_only_metrics_per_case.csv'
    metrics_df.to_csv(metrics_csv, index=False)

    summary_rows = []
    numeric_cols = [c for c in metrics_df.columns if c not in {'case_id', 'prediction_file', 'reference_file'}]
    for col in numeric_cols:
        vals = pd.to_numeric(metrics_df[col], errors='coerce').dropna()
        if len(vals) == 0:
            continue
        summary_rows.append({
            'label': 'PHE',
            'metric': col,
            'mean': float(vals.mean()),
            'median': float(vals.median()),
            'std': float(vals.std(ddof=0)),
            'n': int(len(vals)),
        })
    summary_df = pd.DataFrame(summary_rows)
    summary_csv = OUTPUT_ROOT / '02_12b_kaggle_phe_only_metrics_summary.csv'
    summary_df.to_csv(summary_csv, index=False)

    print('Foreground mean from nnU-Net summary:')
    print(json.dumps(summary.get('foreground_mean', {}), indent=2))
    print('Wrote:', metrics_csv)
    print('Wrote:', summary_csv)
    display(summary_df)
else:
    print('No summary yet:', SUMMARY_JSON)
    print('Run train -> predict -> evaluate first.')
# Out:
# Foreground mean from nnU-Net summary:
# {
#   "Dice": 0.3837162045556275,
#   "FN": 927.8181818181819,
#   "FP": 2267.909090909091,
#   "IoU": 0.260337174966231,
#   "TN": 7835768.818181818,
#   "TP": 1524.1818181818182,
#   "n_pred": 3792.090909090909,
#   "n_ref": 2452.0
# }
# Wrote: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/02_12b_kaggle_phe_only_metrics_per_case.csv
# Wrote: /kaggle/working/outputs_02_12b_kaggle_nnunet_phe_only_120epochs/02_12b_kaggle_phe_only_metrics_summary.csv
#   label  metric          mean        median            std   n
# 0   PHE    Dice  3.837162e-01  3.226782e-01       0.217361  11
# 1   PHE      FN  9.278182e+02  6.930000e+02    1070.131073  11
# 2   PHE      FP  2.267909e+03  1.596000e+03    2181.808860  11
# 3   PHE     IoU  2.603372e-01  1.923770e-01       0.171790  11
# 4   PHE      TN  7.835769e+06  8.382567e+06  800686.468904  11
# 5   PHE      TP  1.524182e+03  7.470000e+02    1684.394675  11
# 6   PHE  n_pred  3.792091e+03  2.824000e+03    3380.190943  11
# 7   PHE   n_ref  2.452000e+03  1.635000e+03    2110.821512  11

# %% [markdown]
# ## Compare with 02_14
#
# Dung notebook nay lam baseline PHE-only 120 epoch tren Kaggle. So sanh voi `02_15` 60 epoch va `02_14` ICH-prior bang cung test split 11 case:
#
# - `02_12b`: CT -> PHE, 120 epochs
# - `02_14`: CT + ICH_teacher_prior -> PHE
#
# Neu `02_14` tot hon ro ret, ICH teacher prior co tac dung. Neu khong, can xem lai chat luong prior hoac cach dua prior vao channel.
